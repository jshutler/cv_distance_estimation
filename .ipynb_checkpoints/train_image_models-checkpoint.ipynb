# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import cv2
# import the necessary packages
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# from keras.models import Sequential
# from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
# from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import time
from math import sqrt

from plot_keras_history import show_history, plot_history

def get_encoding(series):
    #getting our classes
    array = series.to_numpy().reshape(-1,1)
    encoder = OneHotEncoder().fit(array)
    return encoder.transform(array).toarray(), encoder

def setup_keras_model(model, layers):
    for layer in layers:
        model.add(layer)
    
    print(model.summary())


def rmse(x,y):
    return sqrt(mean_squared_error(x,y))

    
def update_metrics(metric_df,df_test, preds, targets_str, metrics, model_name, input_features=None):    
    
    metric_df.loc[model_name, "input_features"] = input_features
    human_rows = df_test["class"] == "Pedestrian"
    hdf = df_test[human_rows]
    print(len(human_rows))
    print(len(pred))
    human_preds = [pred[human_rows] for pred in preds]
    
    #evaluate the targets
    for i, s in enumerate(targets_str):
        target = df_test[s]
        
        print(metrics[i](preds[i], target))
        metric = metrics[i](preds[i], target)
        metric_df.loc[model_name, f"{metrics[i].__name__}_total"] = metric
        
        #predict error for human targets only
        target = hdf[s]
        metric = metrics[i](human_preds[i], target)
        metric_df.loc[model_name, f"{metrics[i].__name__}_human"] = metric  
    
    
    
    
 

# update_metrics(metric_df, df_test["dist_feet"], df_test, "foo")

# %% [markdown]
# # Initiazling GPU

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)
        
# sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))

# %% [markdown]
# # Custom Generator
# Needed cause the just loading all the images into ram overloads it and crashes jupyter.

# %%
#used because too many images
class My_Custom_Generator(tf.keras.utils.Sequence) :
  
  def __init__(self, image_filenames, labels, batch_size, img_dir):
    self.image_filenames = image_filenames
    self.labels = labels
    self.batch_size = batch_size
    self.img_dir = img_dir
    
  def __len__(self):
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
    
    return np.array([
            cv2.imread(img_dir + str(file_name))
               for file_name in batch_x])/255.0, np.array(batch_y)

# %% [markdown]
# # Train Test Split and writing Update metric df

# %%
img_dir = "data/training/image_2"

n = 5

df = pd.read_csv("data/labels.csv")

df_train, df_test = train_test_split(df)

df_train.reset_index(inplace=True)
df_test.reset_index(inplace=True)

model_name = "bounding_box_only"


metric_df = pd.read_csv("metric_df_bb_only.csv", index_col=0)

# %% [markdown]
# # Setting up batch generators for images

# %%
#setting up train and test splits
batch_size = 10
n = df_train.shape[0]
# n = 10000
batch_training = df_train.head(n)
batch_testing = df_test.head(n)

#initializing generators
my_training_batch_generator = My_Custom_Generator(batch_training["filename_bb"], batch_training["dist_feet"], batch_size, img_dir)
my_testing_batch_generator = My_Custom_Generator(batch_testing["filename_bb"], batch_testing["dist_feet"], batch_size, img_dir)


#setting up image directroy where the images will be coming from
img_dir = "data/training/image_2_bounding/"
#getting input shape 

image_shape = cv2.imread(img_dir + '/0.png').shape

# %% [markdown]
# # Image with Bounding Box Only Training

# %%
#Model pathing and file names
model_name = "img_w_bb_only"






#_________________________________________Model Training
model = keras.models.Sequential()


layers = [keras.layers.Conv2D(500, kernel_size=3, activation="relu", input_shape=image_shape),
         keras.layers.AveragePooling2D(),
         keras.layers.Conv2D(250, kernel_size=3, activation="relu"),
         keras.layers.AveragePooling2D(),
         keras.layers.Flatten(),
         keras.layers.Dense(100, activation="relu"),
         keras.layers.Dense(32, activation="relu"),
         keras.layers.Dense(1)]


setup_keras_model(model, layers)


model.summary()
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, decay=0.00001),         )
history = model.fit(my_training_batch_generator, batch_size=32, epochs=10, verbose=2)

# ----------- save model and weights ----------- #
model_json = model.to_json()
with open("models/{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)

model.save_weights("models/{}.h5".format(model_name))
print("Saved model to disk")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 94, 94, 500)       14000
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 47, 47, 500)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 45, 250)       1125250
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 22, 22, 250)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 121000)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               12100100
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                3232
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 13,242,615
# Trainable params: 13,242,615
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 94, 94, 500)       14000
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 47, 47, 500)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 45, 250)       1125250
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 22, 22, 250)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 121000)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               12100100
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                3232
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 13,242,615
# Trainable params: 13,242,615
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# <ipython-input-9-09d96e313110>:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# 3043/3043 - 64s - loss: 1758.8315
# Epoch 2/10
# 3043/3043 - 63s - loss: 767.1980
# Epoch 3/10
# 3043/3043 - 63s - loss: 532.0736
# Epoch 4/10
# 3043/3043 - 63s - loss: 402.0941
# Epoch 5/10
# 3043/3043 - 63s - loss: 328.0611
# Epoch 6/10
# 3043/3043 - 66s - loss: 274.9467
# Epoch 7/10
# 3043/3043 - 66s - loss: 235.0626
# Epoch 8/10
# 3043/3043 - 66s - loss: 202.1594
# Epoch 9/10
# 3043/3043 - 66s - loss: 172.2305
# Epoch 10/10
# 3043/3043 - 64s - loss: 146.9661
# Saved model to disk

# %%
plot_history(history, path=f"results_history/{model_name}")
# Out:
# (<Figure size 360x360 with 1 Axes>,
#  <AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>)

# %%
pred = model.predict(my_testing_batch_generator)

update_metrics(metric_df, df_test, [pred],["dist_feet"], [rmse], model_name)

print(rmse(pred, df_test["dist_feet"]))

metric_df
# Out:
# <ipython-input-9-09d96e313110>:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# 10143
# 10143
# 17.015771564379225
# 17.015771564379225
#                                            input_features  rmse_total  \
# 0                         ['pixel_height', 'pixel_width']   56.843238
# bounding_box             ['xmin', 'ymin', 'xmax', 'ymax']   14.708891
# pixel_model              ['xmin', 'xmax', 'ymin', 'ymax']   14.871484
# human_bb_model           ['xmin', 'xmax', 'ymin', 'ymax']   36.603309
# bb_w_class      ['xmin', 'ymin', 'xmax', 'ymax', 'class']    8.590021
# img_w_bb_only                                        None   17.015772
#
#                 rmse_human
# 0                50.657617
# bounding_box      7.309751
# pixel_model       9.531798
# human_bb_model   36.603309
# bb_w_class        8.477834
# img_w_bb_only    14.674452

# %%
a = {"a": "class", "b": "dist_feet"}
sub_df = df[["class", "xmin", "xmax"]]

# sub_df.apply(lambda col: get_encoding(col) if isinstance(col.dtypes, object) else col, axis=1)

a = np.array([[1,2,3], [11,12,13]])



e, encoder = get_encoding(df["class"])


np.hstack([e, df[["xmin", "xmax"]].values])


df["xmin"].dtype == object
# Out:
# False

# %% [markdown]
# # Image with Bounding Box and Class

# %%
from pprint import pprint
#used because too many images
class functional_api_generator(tf.keras.utils.Sequence):
  def __init__(self, df: pd.DataFrame, filenames: pd.Series, input_features: {str: [str],},
               output_features: {str: [str],}, batch_size: int, img_dir: str):
    self.df = df
    
    self.input_features = {}
    self.output_features = {}
    
    
    #input data
    for feature_layer_key, df_key in input_features.items():
        data = self.df[df_key]
        self.input_features[feature_layer_key] = get_encoding(data)[0] if data.dtype == object else data.values
    
    #output data
    for output_layer_key, df_key in output_features.items():
        data = self.df[df_key]
        self.output_features[output_layer_key] = get_encoding(data)[0] if data.dtype == object else data.values
        
#     print(self.input_features["class"])
#     print(self.output_features["angle"])
    #filenames
    self.image_filenames = filenames
    
    #miscelaneous
    self.batch_size = batch_size
    self.img_dir = img_dir
    
    #encoders
    encoders = {}
  def __len__(self):
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx):
    

    start = idx * self.batch_size
    stop = (idx+1) * self.batch_size

    
    input_batch = {key: value[start:stop] for key, value in self.input_features.items()}
    output_batch = {key: value[start:stop] for key, value in self.output_features.items()}
    
    input_batch["img"] = np.array([cv2.imread(img_dir + str(file_name)) 
                                    for file_name in self.image_filenames[start:stop]])
    
  
#     print(type(input_batch["class"][0]))
#     print(type(output_batch["angle"][0]))
#     pprint(input_batch["class"][0])

#     pprint(output_batch["angle"][0])
    
#     pprint(output_batch.keys())
    
    return input_batch, output_batch

# %%
type(e)

# %% [markdown]
# ## Getting inputs

# %%
model_name = "img_w_bb_and_class"

#class encodings
# train_class, class_encoder = get_encoding(df_train["class"])
test_class, class_encoder = get_encoding(df_test["class"])

class_shape = test_class[0].shape

#angle output encodings
# train_angle = get_encoding(df_train.angle_discrete)[0]
test_angle, angle_encoder = get_encoding(df_test.angle_discrete)
angle_shape = test_angle[0].shape

#images already done
img_input = keras.Input(shape=image_shape, name="img")
class_input = keras.Input(shape=class_shape, name="class")




train_generator_angle = functional_api_generator(df_test, df_test["filename_bb"], {"class": "class"},
                                                 {"distance": "dist_feet", "angle": "angle_discrete"},
                                                 batch_size, img_dir)

test_generator_angle = functional_api_generator(df_test, df_test["filename_bb"], {"class": "class"},
                                                 {"distance": "dist_feet", "angle": "angle_discrete"},
                                                 batch_size, img_dir)

train_generator_dist = functional_api_generator(df_train, df_train["filename_bb"], {"class": "class"},
                                                 {"distance": "dist_feet"},
                                                 batch_size, img_dir)

test_generator_dist = functional_api_generator(df_test, df_test["filename_bb"], {"class": "class"},
                                                 {"distance": "dist_feet"},
                                                 batch_size, img_dir)

# %% [markdown]
# ## Setup Model

# %%
#image layers
img_layer = keras.layers.Conv2D(500, kernel_size=3, activation="relu")(img_input)
img_layer = keras.layers.AveragePooling2D()(img_layer)
img_layer = keras.layers.Conv2D(250, kernel_size=3, activation="relu")(img_layer)
img_layer = keras.layers.AveragePooling2D()(img_layer)
img_layer = keras.layers.Flatten()(img_layer)

#class layers
class_layer = keras.layers.Dense(30, kernel_initializer='normal', activation='relu')(class_input)
class_layer = keras.layers.Dense(15, kernel_initializer='normal', activation='relu')(class_layer)
class_layer = keras.layers.Dense(8, kernel_initializer='normal', activation='relu')(class_layer)

#concatanate the two layers
combined_layer = keras.layers.concatenate([img_layer, class_layer])

combined_layer = keras.layers.Dense(100, activation="relu")(combined_layer)
combined_layer = keras.layers.Dense(32, activation="relu")(combined_layer)

#output layers
dist_layer = keras.layers.Dense(1, name="distance")(combined_layer)
angle_layer = keras.layers.Dense(angle_shape[0], name="angle")(combined_layer)



#defining full model
dist_model = keras.Model(
    inputs=[img_input, class_input],
    outputs=[dist_layer],
)

dist_and_angle_model = keras.Model(
    inputs=[img_input, class_input],
    outputs=[dist_layer, angle_layer]
)

# %%
keras.utils.plot_model(dist_and_angle_model, "dist_and_angle.png", show_shapes=True)

# %%
dist_and_angle_model.compile(loss={"distance": 'mean_squared_error', "angle": keras.losses.CategoricalCrossentropy(from_logits=True)}, 
                   optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, decay=0.00001))

# %%
# train dist_model
history = dist_and_angle_model.fit(
    train_generator_angle,
    batch_size=32,epochs=10, verbose=2
)
# Out:
# <ipython-input-16-00f4cc7ad41d>:34: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# Epoch 1/10
# 1015/1015 - 23s - loss: 1729.2908 - distance_loss: 1703.6030 - angle_loss: 25.6881
# Epoch 2/10
# 1015/1015 - 23s - loss: 689.5266 - distance_loss: 669.5257 - angle_loss: 20.0016
# Epoch 3/10
# 1015/1015 - 23s - loss: 406.7133 - distance_loss: 390.0272 - angle_loss: 16.6861
# Epoch 4/10
# 1015/1015 - 22s - loss: 287.5550 - distance_loss: 274.0350 - angle_loss: 13.5202
# Epoch 5/10
# 1015/1015 - 23s - loss: 205.4653 - distance_loss: 193.6148 - angle_loss: 11.8507
# Epoch 6/10
# 1015/1015 - 23s - loss: 149.1626 - distance_loss: 138.7923 - angle_loss: 10.3703
# Epoch 7/10
# 1015/1015 - 22s - loss: 122.0021 - distance_loss: 112.8835 - angle_loss: 9.1187
# Epoch 8/10
# 1015/1015 - 23s - loss: 93.8480 - distance_loss: 85.5854 - angle_loss: 8.2625
# Epoch 9/10
# 1015/1015 - 23s - loss: 88.5019 - distance_loss: 81.0685 - angle_loss: 7.4334
# Epoch 10/10
# 1015/1015 - 23s - loss: 76.1206 - distance_loss: 69.2444 - angle_loss: 6.8763

# %%
plot_history(history, path=f"results_history/{model_name}")
# Out:
# (<Figure size 1080x360 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Distance loss'}, xlabel='Epochs', ylabel='Distance loss'>,
#         <AxesSubplot:title={'center':'Angle loss'}, xlabel='Epochs', ylabel='Angle loss'>],
#        dtype=object))

# %%
model_name = "image_w_class_distance_and_angle"
# ----------- save model and weights ----------- #
model_json = dist_and_angle_model.to_json()
with open("models/{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)

model.save_weights("models/{}.h5".format(dist_and_angle_model))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
dist_pred, angle_pred = dist_and_angle_model.predict(test_generator_angle)
from sklearn.metrics import accuracy_score


angle_pred = angle_encoder.inverse_transform(angle_pred)


update_metrics(metric_df,
               df_test, 
               (dist_pred, angle_pred),
               ("dist_feet", "angle_discrete"),
               (rmse, accuracy_score),
               "image+class_find~dist+angle")

metric_df
# Out:
# <ipython-input-16-00f4cc7ad41d>:34: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# 10143
# 10143
# 11.270039399546812
# 0.43557132998126785
#                                                         input_features  \
# 0                                      ['pixel_height', 'pixel_width']
# bounding_box                          ['xmin', 'ymin', 'xmax', 'ymax']
# pixel_model                           ['xmin', 'xmax', 'ymin', 'ymax']
# human_bb_model                        ['xmin', 'xmax', 'ymin', 'ymax']
# bb_w_class                   ['xmin', 'ymin', 'xmax', 'ymax', 'class']
# img_w_bb_only                                                     None
# image+class_find~dist+angle                                       None
#
#                              rmse_total  rmse_human  accuracy_score_total  \
# 0                             56.843238   50.657617                   NaN
# bounding_box                  14.708891    7.309751                   NaN
# pixel_model                   14.871484    9.531798                   NaN
# human_bb_model                36.603309   36.603309                   NaN
# bb_w_class                     8.590021    8.477834                   NaN
# img_w_bb_only                 17.015772   14.674452                   NaN
# image+class_find~dist+angle   11.270039    9.953169              0.435571
#
#                              accuracy_score_human
# 0                                             NaN
# bounding_box                                  NaN
# pixel_model                                   NaN
# human_bb_model                                NaN
# bb_w_class                                    NaN
# img_w_bb_only                                 NaN
# image+class_find~dist+angle              0.234317

# %%
dist_model.compile(loss={"distance": "mean_squared_error"},
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, decay=0.00001))

dist_model_history = dist_model.fit(train_generator_dist,
                    batch_size=32,epochs=10, verbose=2)
# Out:
# Epoch 1/10
# <ipython-input-16-00f4cc7ad41d>:34: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# 3043/3043 - 66s - loss: 245.6537
# Epoch 2/10
# 3043/3043 - 66s - loss: 128.8317
# Epoch 3/10
# 3043/3043 - 66s - loss: 85.1958
# Epoch 4/10
# 3043/3043 - 66s - loss: 63.5145
# Epoch 5/10
# 3043/3043 - 67s - loss: 50.1692
# Epoch 6/10
# 3043/3043 - 67s - loss: 39.2188
# Epoch 7/10
# 3043/3043 - 67s - loss: 33.5658
# Epoch 8/10
# 3043/3043 - 66s - loss: 28.3388
# Epoch 9/10
# 3043/3043 - 67s - loss: 23.7941
# Epoch 10/10
# 3043/3043 - 66s - loss: 21.0936

# %%
plot_history(history, path=f"results_history/{model_name}")
# Out:
# (<Figure size 1080x360 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Distance loss'}, xlabel='Epochs', ylabel='Distance loss'>,
#         <AxesSubplot:title={'center':'Angle loss'}, xlabel='Epochs', ylabel='Angle loss'>],
#        dtype=object))

# %%
model_name = "image_w_class_distance"
# ----------- save model and weights ----------- #
model_json = dist_model.to_json()
with open("models/{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)

model.save_weights("models/{}.h5".format(model))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
pred = dist_model.predict(test_generator_dist)


print(pred.reshape(-1,1).shape)

update_metrics(metric_df,
               df_test, 
               [pred],
               ["dist_feet"],
               [rmse],
               "image+class_find~dist")

metric_df
# Out:
# <ipython-input-16-00f4cc7ad41d>:34: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
# (10143, 1)
# 10143
# 10143
# 8.283799914401294
#                                                         input_features  \
# 0                                      ['pixel_height', 'pixel_width']
# bounding_box                          ['xmin', 'ymin', 'xmax', 'ymax']
# pixel_model                           ['xmin', 'xmax', 'ymin', 'ymax']
# human_bb_model                        ['xmin', 'xmax', 'ymin', 'ymax']
# bb_w_class                   ['xmin', 'ymin', 'xmax', 'ymax', 'class']
# img_w_bb_only                                                     None
# image+class_find~dist+angle                                       None
# image+class_find~dist                                             None
#
#                              rmse_total  rmse_human  accuracy_score_total  \
# 0                             56.843238   50.657617                   NaN
# bounding_box                  14.708891    7.309751                   NaN
# pixel_model                   14.871484    9.531798                   NaN
# human_bb_model                36.603309   36.603309                   NaN
# bb_w_class                     8.590021    8.477834                   NaN
# img_w_bb_only                 17.015772   14.674452                   NaN
# image+class_find~dist+angle   11.270039    9.953169              0.435571
# image+class_find~dist          8.283800    8.058502                   NaN
#
#                              accuracy_score_human
# 0                                             NaN
# bounding_box                                  NaN
# pixel_model                                   NaN
# human_bb_model                                NaN
# bb_w_class                                    NaN
# img_w_bb_only                                 NaN
# image+class_find~dist+angle              0.234317
# image+class_find~dist                         NaN
