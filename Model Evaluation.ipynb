# %%
import pandas as pd 
from sklearn.metrics import mean_squared_error
from math import sqrt

df = pd.read_csv("data/predictions.csv")


sqrt(mean_squared_error(df.zloc, df.zloc_pred))
# Out:
# 4.531104746504947
